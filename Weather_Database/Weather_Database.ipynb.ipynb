# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 731

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | iracoubo
# Processing Record 3 of Set 1 | port-cartier
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | nieuwpoort
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | portland
# Processing Record 8 of Set 1 | belmonte
# Processing Record 9 of Set 1 | kavaratti
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | faya
# Processing Record 13 of Set 1 | boston
# Processing Record 14 of Set 1 | solnechnyy
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | angoche
# Processing Record 17 of Set 1 | ostrovnoy
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | vostok
# Processing Record 20 of Set 1 | damghan
# Processing Record 21 of Set 1 | mount isa
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | yuncheng
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | morant bay
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | honningsvag
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | laguna
# Processing Record 36 of Set 1 | merced
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | porbandar
# Processing Record 42 of Set 1 | dawei
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | tieli
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | concordia
# Processing Record 50 of Set 1 | kahului
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | tabas
# Processing Record 4 of Set 2 | meadow lake
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | vila velha
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | sao domingos do prata
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | evensk
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | bayir
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | bahia honda
# Processing Record 24 of Set 2 | imeni poliny osipenko
# Processing Record 25 of Set 2 | vanino
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | nhulunbuy
# Processing Record 28 of Set 2 | san ignacio
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | aswan
# Processing Record 31 of Set 2 | ekibastuz
# Processing Record 32 of Set 2 | alappuzha
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | margate
# Processing Record 36 of Set 2 | aloleng
# Processing Record 37 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | srednekolymsk
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | shenjiamen
# Processing Record 43 of Set 2 | kalga
# Processing Record 44 of Set 2 | gao
# Processing Record 45 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 2 | norman wells
# Processing Record 47 of Set 2 | adrar
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | dukat
# Processing Record 50 of Set 2 | ilulissat
# Processing Record 1 of Set 3 | peniche
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | lazaro cardenas
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | moron
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | ponta delgada
# Processing Record 11 of Set 3 | pangnirtung
# Processing Record 12 of Set 3 | ingham
# Processing Record 13 of Set 3 | vila franca do campo
# Processing Record 14 of Set 3 | acari
# Processing Record 15 of Set 3 | torbay
# Processing Record 16 of Set 3 | rudbar
# Processing Record 17 of Set 3 | sire
# Processing Record 18 of Set 3 | tromso
# Processing Record 19 of Set 3 | zurrieq
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | arica
# Processing Record 22 of Set 3 | kununurra
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | te anau
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | itarema
# Processing Record 27 of Set 3 | orje
# Processing Record 28 of Set 3 | kieta
# Processing Record 29 of Set 3 | nisia floresta
# Processing Record 30 of Set 3 | benguela
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | tres passos
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | pandan
# Processing Record 35 of Set 3 | thunder bay
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | temba
# Processing Record 39 of Set 3 | gura humorului
# Processing Record 40 of Set 3 | bokoro
# Processing Record 41 of Set 3 | chandbali
# Processing Record 42 of Set 3 | coihaique
# Processing Record 43 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 3 | nishihara
# Processing Record 45 of Set 3 | ahipara
# Processing Record 46 of Set 3 | myra
# Processing Record 47 of Set 3 | bara
# Processing Record 48 of Set 3 | andenes
# Processing Record 49 of Set 3 | ngaoundere
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | ostrov
# Processing Record 2 of Set 4 | sao miguel do araguaia
# Processing Record 3 of Set 4 | marawi
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | dunedin
# Processing Record 6 of Set 4 | pangkalanbuun
# Processing Record 7 of Set 4 | lloydminster
# Processing Record 8 of Set 4 | ust-kuyga
# Processing Record 9 of Set 4 | tilichiki
# Processing Record 10 of Set 4 | urumqi
# Processing Record 11 of Set 4 | toledo
# Processing Record 12 of Set 4 | gazanjyk
# Processing Record 13 of Set 4 | dudinka
# Processing Record 14 of Set 4 | zistersdorf
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 17 of Set 4 | havoysund
# Processing Record 18 of Set 4 | lerwick
# Processing Record 19 of Set 4 | izumo
# Processing Record 20 of Set 4 | sakakah
# Processing Record 21 of Set 4 | rafai
# Processing Record 22 of Set 4 | hithadhoo
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | gimli
# Processing Record 25 of Set 4 | manta
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | alofi
# Processing Record 28 of Set 4 | dengfeng
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | inuvik
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | guliston
# Processing Record 34 of Set 4 | vila
# Processing Record 35 of Set 4 | imperial beach
# Processing Record 36 of Set 4 | syumsi
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | vao
# Processing Record 39 of Set 4 | flin flon
# Processing Record 40 of Set 4 | port augusta
# Processing Record 41 of Set 4 | hagi
# Processing Record 42 of Set 4 | yinchuan
# Processing Record 43 of Set 4 | fergus falls
# Processing Record 44 of Set 4 | garhshankar
# Processing Record 45 of Set 4 | san gavino monreale
# Processing Record 46 of Set 4 | soyo
# Processing Record 47 of Set 4 | okhotsk
# Processing Record 48 of Set 4 | khed brahma
# Processing Record 49 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | kattivakkam
# Processing Record 3 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 5 | fort nelson
# Processing Record 5 of Set 5 | inyonga
# Processing Record 6 of Set 5 | thinadhoo
# Processing Record 7 of Set 5 | barsovo
# Processing Record 8 of Set 5 | shemonaikha
# Processing Record 9 of Set 5 | xiuyan
# Processing Record 10 of Set 5 | spas-demensk
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | vanimo
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | pevek
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | cidreira
# Processing Record 17 of Set 5 | santa fe
# Processing Record 18 of Set 5 | port alfred
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | khani
# Processing Record 21 of Set 5 | gatesville
# Processing Record 22 of Set 5 | comodoro rivadavia
# Processing Record 23 of Set 5 | tuatapere
# Processing Record 24 of Set 5 | auki
# Processing Record 25 of Set 5 | kestel
# Processing Record 26 of Set 5 | pontian kecil
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | pyshchug
# Processing Record 29 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 30 of Set 5 | alice springs
# Processing Record 31 of Set 5 | sulphur springs
# Processing Record 32 of Set 5 | usinsk
# Processing Record 33 of Set 5 | kincardine
# Processing Record 34 of Set 5 | ahuatempan
# Processing Record 35 of Set 5 | qaqortoq
# Processing Record 36 of Set 5 | yertsevo
# Processing Record 37 of Set 5 | glubokiy
# Processing Record 38 of Set 5 | baykit
# Processing Record 39 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 5 | lanzhou
# Processing Record 41 of Set 5 | hualmay
# Processing Record 42 of Set 5 | mayumba
# Processing Record 43 of Set 5 | tambacounda
# Processing Record 44 of Set 5 | bastia
# Processing Record 45 of Set 5 | sokoni
# Processing Record 46 of Set 5 | the valley
# Processing Record 47 of Set 5 | chabahar
# Processing Record 48 of Set 5 | kholmogory
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 50 of Set 5 | los llanos de aridane
# Processing Record 1 of Set 6 | teeli
# Processing Record 2 of Set 6 | abu kamal
# Processing Record 3 of Set 6 | inhambane
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | korla
# Processing Record 6 of Set 6 | pontianak
# Processing Record 7 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 8 of Set 6 | centralia
# Processing Record 9 of Set 6 | yulara
# Processing Record 10 of Set 6 | sabha
# Processing Record 11 of Set 6 | muros
# Processing Record 12 of Set 6 | bonavista
# Processing Record 13 of Set 6 | raichur
# Processing Record 14 of Set 6 | saint-augustin
# Processing Record 15 of Set 6 | deputatskiy
# Processing Record 16 of Set 6 | palauig
# Processing Record 17 of Set 6 | talnakh
# Processing Record 18 of Set 6 | clearlake
# Processing Record 19 of Set 6 | havre-saint-pierre
# Processing Record 20 of Set 6 | chinsali
# Processing Record 21 of Set 6 | mayor pablo lagerenza
# Processing Record 22 of Set 6 | nelson bay
# Processing Record 23 of Set 6 | winnemucca
# Processing Record 24 of Set 6 | canutama
# Processing Record 25 of Set 6 | san patricio
# Processing Record 26 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 6 | tias
# Processing Record 28 of Set 6 | ribeira grande
# Processing Record 29 of Set 6 | sistranda
# Processing Record 30 of Set 6 | maragogi
# Processing Record 31 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | cranbrook
# Processing Record 33 of Set 6 | kenai
# Processing Record 34 of Set 6 | chimbote
# Processing Record 35 of Set 6 | ancud
# Processing Record 36 of Set 6 | turukhansk
# Processing Record 37 of Set 6 | sonoita
# Processing Record 38 of Set 6 | wahiawa
# Processing Record 39 of Set 6 | aasiaat
# Processing Record 40 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 41 of Set 6 | bujak
# Processing Record 42 of Set 6 | dhilwan
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | mosquera
# Processing Record 45 of Set 6 | taltal
# Processing Record 46 of Set 6 | coahuayana
# Processing Record 47 of Set 6 | santa maria
# Processing Record 48 of Set 6 | monduli
# Processing Record 49 of Set 6 | pa daet
# Processing Record 50 of Set 6 | champasak
# Processing Record 1 of Set 7 | the pas
# Processing Record 2 of Set 7 | tagusao
# Processing Record 3 of Set 7 | shaowu
# Processing Record 4 of Set 7 | lebu
# Processing Record 5 of Set 7 | sorland
# Processing Record 6 of Set 7 | valparaiso
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | hay river
# Processing Record 9 of Set 7 | naze
# Processing Record 10 of Set 7 | colares
# Processing Record 11 of Set 7 | xining
# Processing Record 12 of Set 7 | hami
# Processing Record 13 of Set 7 | constitucion
# Processing Record 14 of Set 7 | xacmaz
# Processing Record 15 of Set 7 | ixtapa
# Processing Record 16 of Set 7 | puerto del rosario
# Processing Record 17 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 7 | bela
# Processing Record 19 of Set 7 | mana
# Processing Record 20 of Set 7 | rio grande
# Processing Record 21 of Set 7 | benemerito de las americas
# Processing Record 22 of Set 7 | okha
# Processing Record 23 of Set 7 | shelburne
# Processing Record 24 of Set 7 | champerico
# Processing Record 25 of Set 7 | sao miguel do tapuio
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | mount gambier
# Processing Record 28 of Set 7 | requena
# Processing Record 29 of Set 7 | severo-kurilsk
# Processing Record 30 of Set 7 | cairns
# Processing Record 31 of Set 7 | mehamn
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | chuy
# Processing Record 34 of Set 7 | fresnillo
# Processing Record 35 of Set 7 | padang
# Processing Record 36 of Set 7 | yumen
# Processing Record 37 of Set 7 | karla
# Processing Record 38 of Set 7 | samarai
# Processing Record 39 of Set 7 | port macquarie
# Processing Record 40 of Set 7 | midland
# Processing Record 41 of Set 7 | russell
# Processing Record 42 of Set 7 | mandera
# Processing Record 43 of Set 7 | najran
# Processing Record 44 of Set 7 | nome
# Processing Record 45 of Set 7 | paamiut
# Processing Record 46 of Set 7 | kruisfontein
# Processing Record 47 of Set 7 | zyryanka
# Processing Record 48 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 7 | broken hill
# Processing Record 50 of Set 7 | catalina
# Processing Record 1 of Set 8 | san luis
# Processing Record 2 of Set 8 | esperance
# Processing Record 3 of Set 8 | ocampo
# Processing Record 4 of Set 8 | port lincoln
# Processing Record 5 of Set 8 | castro
# Processing Record 6 of Set 8 | dabat
# Processing Record 7 of Set 8 | kozhva
# Processing Record 8 of Set 8 | caruray
# Processing Record 9 of Set 8 | kavieng
# Processing Record 10 of Set 8 | jacareacanga
# Processing Record 11 of Set 8 | celestun
# Processing Record 12 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 8 | cabo san lucas
# Processing Record 14 of Set 8 | tual
# Processing Record 15 of Set 8 | haines junction
# Processing Record 16 of Set 8 | olinda
# Processing Record 17 of Set 8 | beni
# Processing Record 18 of Set 8 | martapura
# Processing Record 19 of Set 8 | port blair
# Processing Record 20 of Set 8 | codrington
# Processing Record 21 of Set 8 | davidson
# Processing Record 22 of Set 8 | husavik
# Processing Record 23 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 8 | athabasca
# Processing Record 26 of Set 8 | hovd
# Processing Record 27 of Set 8 | iseyin
# Processing Record 28 of Set 8 | poso
# Processing Record 29 of Set 8 | victoria
# Processing Record 30 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 8 | alihe
# Processing Record 32 of Set 8 | axim
# Processing Record 33 of Set 8 | nieves
# Processing Record 34 of Set 8 | avera
# Processing Record 35 of Set 8 | taoudenni
# Processing Record 36 of Set 8 | terrace
# Processing Record 37 of Set 8 | booue
# Processing Record 38 of Set 8 | praia
# Processing Record 39 of Set 8 | himora
# City not found. Skipping...
# Processing Record 40 of Set 8 | saint-philippe
# Processing Record 41 of Set 8 | bathsheba
# Processing Record 42 of Set 8 | aligudarz
# Processing Record 43 of Set 8 | sampit
# Processing Record 44 of Set 8 | leningradskiy
# Processing Record 45 of Set 8 | matagami
# Processing Record 46 of Set 8 | santa rosa
# Processing Record 47 of Set 8 | henties bay
# Processing Record 48 of Set 8 | raudeberg
# Processing Record 49 of Set 8 | barra da estiva
# Processing Record 50 of Set 8 | lata
# Processing Record 1 of Set 9 | northam
# Processing Record 2 of Set 9 | dingle
# Processing Record 3 of Set 9 | maceio
# Processing Record 4 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 9 | bethel
# Processing Record 6 of Set 9 | acapulco
# Processing Record 7 of Set 9 | morrope
# Processing Record 8 of Set 9 | suwalki
# Processing Record 9 of Set 9 | joshimath
# Processing Record 10 of Set 9 | kon tum
# Processing Record 11 of Set 9 | huanan
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | mutis
# Processing Record 14 of Set 9 | cananea
# Processing Record 15 of Set 9 | flinders
# Processing Record 16 of Set 9 | yerbogachen
# Processing Record 17 of Set 9 | nabire
# Processing Record 18 of Set 9 | clyde river
# Processing Record 19 of Set 9 | ondangwa
# Processing Record 20 of Set 9 | winton
# Processing Record 21 of Set 9 | saint-francois
# Processing Record 22 of Set 9 | san vicente de canete
# Processing Record 23 of Set 9 | daru
# Processing Record 24 of Set 9 | tiksi
# Processing Record 25 of Set 9 | blackwater
# Processing Record 26 of Set 9 | bonthe
# Processing Record 27 of Set 9 | high level
# Processing Record 28 of Set 9 | queanbeyan
# Processing Record 29 of Set 9 | poum
# Processing Record 30 of Set 9 | buin
# Processing Record 31 of Set 9 | dryden
# Processing Record 32 of Set 9 | awjilah
# Processing Record 33 of Set 9 | dubbo
# Processing Record 34 of Set 9 | plouzane
# Processing Record 35 of Set 9 | tiznit
# Processing Record 36 of Set 9 | kirakira
# Processing Record 37 of Set 9 | wamba
# Processing Record 38 of Set 9 | quetzaltepec
# City not found. Skipping...
# Processing Record 39 of Set 9 | zeya
# Processing Record 40 of Set 9 | maldonado
# Processing Record 41 of Set 9 | ban nahin
# Processing Record 42 of Set 9 | krasnoturansk
# Processing Record 43 of Set 9 | lasa
# Processing Record 44 of Set 9 | sarangani
# Processing Record 45 of Set 9 | shakiso
# Processing Record 46 of Set 9 | akdepe
# Processing Record 47 of Set 9 | upata
# Processing Record 48 of Set 9 | sao francisco
# Processing Record 49 of Set 9 | labuhan
# Processing Record 50 of Set 9 | xudat
# Processing Record 1 of Set 10 | minab
# Processing Record 2 of Set 10 | salme
# Processing Record 3 of Set 10 | gamba
# Processing Record 4 of Set 10 | abu dhabi
# Processing Record 5 of Set 10 | chilca
# Processing Record 6 of Set 10 | mawlaik
# Processing Record 7 of Set 10 | egvekinot
# Processing Record 8 of Set 10 | kijang
# Processing Record 9 of Set 10 | namibe
# Processing Record 10 of Set 10 | miandrivazo
# Processing Record 11 of Set 10 | mashhad
# Processing Record 12 of Set 10 | touros
# Processing Record 13 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 14 of Set 10 | fortuna
# Processing Record 15 of Set 10 | vizianagaram
# Processing Record 16 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | neiafu
# Processing Record 19 of Set 10 | anloga
# Processing Record 20 of Set 10 | la romana
# Processing Record 21 of Set 10 | bud
# Processing Record 22 of Set 10 | grindavik
# Processing Record 23 of Set 10 | curaca
# Processing Record 24 of Set 10 | homer
# Processing Record 25 of Set 10 | vestmannaeyjar
# Processing Record 26 of Set 10 | obuasi
# Processing Record 27 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 10 | riyadh
# Processing Record 29 of Set 10 | jalu
# Processing Record 30 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 10 | mushie
# Processing Record 32 of Set 10 | guayaramerin
# Processing Record 33 of Set 10 | saint-leu
# Processing Record 34 of Set 10 | plantation
# Processing Record 35 of Set 10 | oranjemund
# Processing Record 36 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 10 | nadigaon
# Processing Record 38 of Set 10 | micheweni
# Processing Record 39 of Set 10 | mogadishu
# Processing Record 40 of Set 10 | cabra
# Processing Record 41 of Set 10 | marienburg
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | jibuti
# Processing Record 44 of Set 10 | agadez
# Processing Record 45 of Set 10 | lukovetskiy
# Processing Record 46 of Set 10 | vuktyl
# Processing Record 47 of Set 10 | hongjiang
# Processing Record 48 of Set 10 | katobu
# Processing Record 49 of Set 10 | whitehorse
# Processing Record 50 of Set 10 | matara
# Processing Record 1 of Set 11 | manokwari
# Processing Record 2 of Set 11 | kedrovyy
# Processing Record 3 of Set 11 | pinheiro machado
# Processing Record 4 of Set 11 | cap malheureux
# Processing Record 5 of Set 11 | tessalit
# Processing Record 6 of Set 11 | kabwe
# Processing Record 7 of Set 11 | narsaq
# Processing Record 8 of Set 11 | cayenne
# Processing Record 9 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 11 | brae
# Processing Record 11 of Set 11 | tacoronte
# Processing Record 12 of Set 11 | sambava
# Processing Record 13 of Set 11 | yunyang
# Processing Record 14 of Set 11 | zaoyang
# Processing Record 15 of Set 11 | pouembout
# Processing Record 16 of Set 11 | torbat-e jam
# Processing Record 17 of Set 11 | kalmunai
# Processing Record 18 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 11 | bubaque
# Processing Record 20 of Set 11 | merauke
# Processing Record 21 of Set 11 | beira
# Processing Record 22 of Set 11 | shellbrook
# Processing Record 23 of Set 11 | kommunar
# Processing Record 24 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 11 | sompeta
# Processing Record 26 of Set 11 | anadyr
# Processing Record 27 of Set 11 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 28 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 11 | tonantins
# Processing Record 30 of Set 11 | bandrele
# Processing Record 31 of Set 11 | turbat
# Processing Record 32 of Set 11 | shimoda
# Processing Record 33 of Set 11 | newport
# Processing Record 34 of Set 11 | baft
# Processing Record 35 of Set 11 | baoding
# Processing Record 36 of Set 11 | ronne
# Processing Record 37 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 11 | pingxiang
# Processing Record 39 of Set 11 | manggar
# Processing Record 40 of Set 11 | palmer
# Processing Record 41 of Set 11 | noumea
# Processing Record 42 of Set 11 | carahue
# Processing Record 43 of Set 11 | kolobrzeg
# Processing Record 44 of Set 11 | ossora
# Processing Record 45 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 11 | marystown
# Processing Record 47 of Set 11 | yeppoon
# Processing Record 48 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 11 | exeter
# Processing Record 50 of Set 11 | oktyabrskiy
# Processing Record 1 of Set 12 | povenets
# Processing Record 2 of Set 12 | agar
# Processing Record 3 of Set 12 | quatre cocos
# Processing Record 4 of Set 12 | beisfjord
# Processing Record 5 of Set 12 | farah
# Processing Record 6 of Set 12 | tuy hoa
# Processing Record 7 of Set 12 | rawson
# Processing Record 8 of Set 12 | gombong
# Processing Record 9 of Set 12 | bonfim
# Processing Record 10 of Set 12 | newtonhill
# Processing Record 11 of Set 12 | nsanje
# Processing Record 12 of Set 12 | choix
# Processing Record 13 of Set 12 | burnie
# Processing Record 14 of Set 12 | podosinovets
# Processing Record 15 of Set 12 | wuchang
# Processing Record 16 of Set 12 | saint-joseph
# Processing Record 17 of Set 12 | almaznyy
# Processing Record 18 of Set 12 | grand-santi
# Processing Record 19 of Set 12 | mattru
# Processing Record 20 of Set 12 | iranshahr
# Processing Record 21 of Set 12 | clarence town
# Processing Record 22 of Set 12 | bodden town
# Processing Record 23 of Set 12 | slavutych
# Processing Record 24 of Set 12 | ilmajoki
# Processing Record 25 of Set 12 | tomatlan
# Processing Record 26 of Set 12 | samandag
# Processing Record 27 of Set 12 | goure
# Processing Record 28 of Set 12 | hailar
# Processing Record 29 of Set 12 | vallenar
# Processing Record 30 of Set 12 | remontnoye
# Processing Record 31 of Set 12 | amta
# Processing Record 32 of Set 12 | port hawkesbury
# Processing Record 33 of Set 12 | monteagudo
# Processing Record 34 of Set 12 | sao jose da coroa grande
# Processing Record 35 of Set 12 | bairiki
# Processing Record 36 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 37 of Set 12 | bobcaygeon
# Processing Record 38 of Set 12 | fairbanks
# Processing Record 39 of Set 12 | gayeri
# Processing Record 40 of Set 12 | pitimbu
# Processing Record 41 of Set 12 | kjollefjord
# Processing Record 42 of Set 12 | bentiu
# Processing Record 43 of Set 12 | dutse
# Processing Record 44 of Set 12 | ahtopol
# Processing Record 45 of Set 12 | ishigaki
# Processing Record 46 of Set 12 | nemuro
# Processing Record 47 of Set 12 | caravelas
# Processing Record 48 of Set 12 | grasse
# Processing Record 49 of Set 12 | swakopmund
# Processing Record 50 of Set 12 | gashua
# Processing Record 1 of Set 13 | trn
# Processing Record 2 of Set 13 | west bay
# Processing Record 3 of Set 13 | poros
# Processing Record 4 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 5 of Set 13 | opuwo
# Processing Record 6 of Set 13 | mitchell
# Processing Record 7 of Set 13 | san policarpo
# Processing Record 8 of Set 13 | tatawin
# Processing Record 9 of Set 13 | imbituba
# Processing Record 10 of Set 13 | svetlyy
# Processing Record 11 of Set 13 | blacksburg
# Processing Record 12 of Set 13 | katherine
# Processing Record 13 of Set 13 | tulun
# Processing Record 14 of Set 13 | santa ana
# Processing Record 15 of Set 13 | lipovtsy
# Processing Record 16 of Set 13 | lieksa
# Processing Record 17 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 19 of Set 13 | meulaboh
# Processing Record 20 of Set 13 | yar-sale
# Processing Record 21 of Set 13 | kokoda
# Processing Record 22 of Set 13 | changli
# Processing Record 23 of Set 13 | payo
# Processing Record 24 of Set 13 | paciran
# Processing Record 25 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 26 of Set 13 | norrtalje
# Processing Record 27 of Set 13 | college
# Processing Record 28 of Set 13 | washougal
# Processing Record 29 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 13 | xam nua
# Processing Record 31 of Set 13 | corning
# Processing Record 32 of Set 13 | kadaya
# Processing Record 33 of Set 13 | okato
# Processing Record 34 of Set 13 | taywarah
# Processing Record 35 of Set 13 | pacific grove
# Processing Record 36 of Set 13 | ozu
# Processing Record 37 of Set 13 | zhaotong
# Processing Record 38 of Set 13 | conde
# Processing Record 39 of Set 13 | sungaipenuh
# Processing Record 40 of Set 13 | neos marmaras
# Processing Record 41 of Set 13 | botro
# Processing Record 42 of Set 13 | san ramon
# Processing Record 43 of Set 13 | pokosnoye
# Processing Record 44 of Set 13 | esmeraldas
# Processing Record 45 of Set 13 | sao joao da barra
# Processing Record 46 of Set 13 | zlobin
# Processing Record 47 of Set 13 | saint-pierre
# Processing Record 48 of Set 13 | nantucket
# Processing Record 49 of Set 13 | aksarayskiy
# Processing Record 50 of Set 13 | beringovskiy
# Processing Record 1 of Set 14 | krasnoslobodsk
# Processing Record 2 of Set 14 | neuquen
# Processing Record 3 of Set 14 | rumoi
# Processing Record 4 of Set 14 | sept-iles
# Processing Record 5 of Set 14 | staryy nadym
# Processing Record 6 of Set 14 | luderitz
# Processing Record 7 of Set 14 | puerto escondido
# Processing Record 8 of Set 14 | biak
# Processing Record 9 of Set 14 | necochea
# Processing Record 10 of Set 14 | maumere
# Processing Record 11 of Set 14 | dali
# Processing Record 12 of Set 14 | wichita falls
# Processing Record 13 of Set 14 | moindou
# Processing Record 14 of Set 14 | san juan
# Processing Record 15 of Set 14 | saint anthony
# Processing Record 16 of Set 14 | linjiang
# Processing Record 17 of Set 14 | waipawa
# Processing Record 18 of Set 14 | borogontsy
# Processing Record 19 of Set 14 | portel
# Processing Record 20 of Set 14 | eyl
# Processing Record 21 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 22 of Set 14 | cascais
# Processing Record 23 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 14 | hays
# Processing Record 25 of Set 14 | eureka
# Processing Record 26 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 14 | kupang
# Processing Record 28 of Set 14 | hervey bay
# Processing Record 29 of Set 14 | phuket
# Processing Record 30 of Set 14 | walvis bay
# Processing Record 31 of Set 14 | cayeli
# Processing Record 32 of Set 14 | viedma
# Processing Record 33 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 14 | chengkung
# City not found. Skipping...
# Processing Record 35 of Set 14 | mareeba
# Processing Record 36 of Set 14 | boissevain
# Processing Record 37 of Set 14 | svetlaya
# Processing Record 38 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 39 of Set 14 | sabang
# Processing Record 40 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 41 of Set 14 | ho
# City not found. Skipping...
# Processing Record 42 of Set 14 | richards bay
# Processing Record 43 of Set 14 | roma
# Processing Record 44 of Set 14 | howard springs
# Processing Record 45 of Set 14 | sakaiminato
# Processing Record 46 of Set 14 | abu samrah
# Processing Record 47 of Set 14 | redlands
# Processing Record 48 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 14 | ewa beach
# Processing Record 50 of Set 14 | bilma
# Processing Record 1 of Set 15 | vrangel
# Processing Record 2 of Set 15 | constantine
# Processing Record 3 of Set 15 | medea
# Processing Record 4 of Set 15 | yurgamysh
# Processing Record 5 of Set 15 | lorengau
# Processing Record 6 of Set 15 | menongue
# Processing Record 7 of Set 15 | ucluelet
# Processing Record 8 of Set 15 | mingguang
# Processing Record 9 of Set 15 | luanda
# Processing Record 10 of Set 15 | hienghene
# Processing Record 11 of Set 15 | kojnare
# Processing Record 12 of Set 15 | hofn
# Processing Record 13 of Set 15 | aquiraz
# Processing Record 14 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 15 of Set 15 | stonewall
# Processing Record 16 of Set 15 | carmen
# Processing Record 17 of Set 15 | eyemouth
# Processing Record 18 of Set 15 | sioux lookout
# Processing Record 19 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 15 | ibra
# Processing Record 21 of Set 15 | alberton
# Processing Record 22 of Set 15 | olga
# Processing Record 23 of Set 15 | ketchikan
# Processing Record 24 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 15 | verkhnevilyuysk
# Processing Record 26 of Set 15 | grenfell
# Processing Record 27 of Set 15 | socorro
# Processing Record 28 of Set 15 | smithers
# Processing Record 29 of Set 15 | west wendover
# Processing Record 30 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 31 of Set 15 | taft
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 668

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kaitangata -46.2817  169.8464     53.35        56          19
# 1      Iracoubo   5.4802  -53.2011     77.45        88         100
# 2  Port-Cartier  50.0334  -66.8654     43.02        89          89
# 3       Ushuaia -54.8000  -68.3000     35.26        87          75
# 4    Nieuwpoort  51.1244    2.7735     56.23        94         100
# 5     Carnarvon -24.8667  113.6333     73.45        26           0
# 6      Portland  45.5234 -122.6762     72.18        63           0
# 7      Belmonte -15.8631  -38.8828     74.52        82          69
# 8     Kavaratti  10.5669   72.6420     81.07        73          91
# 9       Rikitea -23.1203 -134.9692     69.21        62           0
#
#    Wind Speed Current Description Country                 Date
# 0        9.33          few clouds      NZ  2022-10-13 02:45:25
# 1        6.76     overcast clouds      GF  2022-10-13 02:45:26
# 2        5.59     overcast clouds      CA  2022-10-13 02:45:26
# 3       33.38       broken clouds      AR  2022-10-13 02:40:36
# 4        6.91          light rain      BE  2022-10-13 02:45:27
# 5       14.29           clear sky      AU  2022-10-13 02:45:27
# 6        3.00           clear sky      US  2022-10-13 02:41:22
# 7        9.10       broken clouds      BR  2022-10-13 02:45:27
# 8        6.20     overcast clouds      IN  2022-10-13 02:45:28
# 9       15.30           clear sky      PF  2022-10-13 02:44:34

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]

# Recreate the DataFrame by using the new column order
# Display sample data
city_data__no_date_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kaitangata      NZ -46.2817  169.8464     53.35        56          19
# 1      Iracoubo      GF   5.4802  -53.2011     77.45        88         100
# 2  Port-Cartier      CA  50.0334  -66.8654     43.02        89          89
# 3       Ushuaia      AR -54.8000  -68.3000     35.26        87          75
# 4    Nieuwpoort      BE  51.1244    2.7735     56.23        94         100
# 5     Carnarvon      AU -24.8667  113.6333     73.45        26           0
# 6      Portland      US  45.5234 -122.6762     72.18        63           0
# 7      Belmonte      BR -15.8631  -38.8828     74.52        82          69
# 8     Kavaratti      IN  10.5669   72.6420     81.07        73          91
# 9       Rikitea      PF -23.1203 -134.9692     69.21        62           0
#
#    Wind Speed Current Description
# 0        9.33          few clouds
# 1        6.76     overcast clouds
# 2        5.59     overcast clouds
# 3       33.38       broken clouds
# 4        6.91          light rain
# 5       14.29           clear sky
# 6        3.00           clear sky
# 7        9.10       broken clouds
# 8        6.20     overcast clouds
# 9       15.30           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data__no_date_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data__no_date_df.to_csv(output_data_file, index_label="City_ID")
